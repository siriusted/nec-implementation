# %%
# !python ./main.py
# Out:
#   0%|                                        | 8/100000 [00:00<21:01, 79.28it/s]Scores: (score: 12.0 min: 12.0, avg: 12.0, max:  12.0)
#
#   0%|                                       | 16/100000 [00:00<49:10, 33.88it/s]/Users/david.emukpere/Internship/nec-implementation/logger.py:38: RankWarning: Polyfit may be poorly conditioned
#   show_legend=True)
# Scores: (score: 14.0 min: 12.0, avg: 13.0, max:  14.0)
#
#   0%|                                       | 30/100000 [00:00<41:04, 40.56it/s]Scores: (score: 44.0 min: 12.0, avg: 23.333333333333332, max:  44.0)
#
#   0%|                                       | 76/100000 [00:01<19:53, 83.72it/s]Scores: (score: 11.0 min: 11.0, avg: 20.25, max:  44.0)
#
#   0%|                                       | 89/100000 [00:01<24:52, 66.93it/s]Scores: (score: 18.0 min: 11.0, avg: 19.8, max:  44.0)
#
#   0%|                                      | 109/100000 [00:01<26:30, 62.79it/s]Scores: (score: 28.0 min: 11.0, avg: 21.166666666666668, max:  44.0)
#
# ...
